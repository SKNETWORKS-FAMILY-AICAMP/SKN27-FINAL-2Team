# %%
import pandas as pd

df = pd.read_csv('../../etl/preprocessing/history/raw_data//교육부 국사편찬위원회_한국역사용어시소러스 정보_20211028 (1).csv')

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62409 entries, 0 to 62408
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   term_id         62409 non-null  int64
#  1   topterm_id      62409 non-null  int64
#  2   term_name       62409 non-null  str
#  3   term_kind       62409 non-null  int64
#  4   term_ch         61852 non-null  str
#  5   term_remark     12889 non-null  str
#  6   term_attr       358 non-null    str
#  7   term_year       61356 non-null  str
#  8   term_times      60543 non-null  str
#  9   term_lk         61903 non-null  str
#  10  term_desc       61583 non-null  str
#  11  term_user       62409 non-null  int64
#  12  term_created    62409 non-null  str
#  13  term_reference  34101 non-null  str
# dtypes: int64(4), str(10)
# memory usage: 6.7 MB

# %%
df.head(1)
# Out:
#    term_id  topterm_id term_name  term_kind term_ch term_remark term_attr  \
# 0     5617           8         수          2       守         NaN       NaN
#
#    term_year term_times      term_lk  \
# 0  1466-1894       조선시대  정치·행정·법제>인사
#
#                                            term_desc  term_user  \
# 0  조선시대 전설사(典設司)·풍저창(豊儲倉)·광흥창(廣興倉)의 장관과 종친부(宗親府)의...         10
#
#           term_created term_reference
# 0  2003-08-31 12:03:51            NaN

# %%
df=df.drop(columns=['term_id', 'term_kind', 'topterm_id', 'term_remark', 'term_attr', 'term_reference', 'term_created', 'topterm_id', 'term_user'])

# %%
df.head(3)
# Out:
#   term_name term_ch  term_year term_times              term_lk  \
# 0         수       守  1466-1894       조선시대          정치·행정·법제>인사
# 1         수       隋    581-618       삼국시대         역사일반>국가>중국국가
# 2       수구당     守舊黨  1876-1894        개항기  정치·행정·법제>정치>정치조직·단체
#
#                                            term_desc
# 0  조선시대 전설사(典設司)·풍저창(豊儲倉)·광흥창(廣興倉)의 장관과 종친부(宗親府)의...
# 1                                         중국의 통일 왕조.
# 2              개항기 명성황후를 중심으로 형성된 친청적(親淸的) 보수 정치 집단.

# %%
df['term_desc'][0]
# Out:
# '조선시대 전설사(典設司)·풍저창(豊儲倉)·광흥창(廣興倉)의 장관과 종친부(宗親府)의 정4품 관직.'

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62409 entries, 0 to 62408
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   term_name   62409 non-null  str
#  1   term_ch     61852 non-null  str
#  2   term_year   61356 non-null  str
#  3   term_times  60543 non-null  str
#  4   term_lk     61903 non-null  str
#  5   term_desc   61583 non-null  str
# dtypes: str(6)
# memory usage: 2.9 MB

# %%
df.to_csv('../../storage/neo4j/neo4j_import/역사용어.csv', index=False)
